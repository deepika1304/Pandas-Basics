# %%
import pandas as pd
df = pd.read_csv("financial_year.csv")
#To print columns, rows
df.shape
# Out:
# (41715, 10)

# %%
rows, columns = df.shape
#To print Columns 
columns
# Out:
# 10

# %%
#To print Top 5 rows
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
#To print last 5 rows
df.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 41710  Food product manufacturing  Percentage           H37
# 41711  Food product manufacturing  Percentage           H38
# 41712  Food product manufacturing  Percentage           H39
# 41713  Food product manufacturing  Percentage           H40
# 41714  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 41710                          Quick ratio  Financial ratios    52
# 41711  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
#To print specific rows 
df[2:5]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code                      Variable_name  \
# 2  Dollars (millions)           H05  Interest, dividends and donations
# 3  Dollars (millions)           H07               Non-operating income
# 4  Dollars (millions)           H08                  Total expenditure
#
#        Variable_category    Value  \
# 2  Financial performance   49,593
# 3  Financial performance   33,020
# 4  Financial performance  654,404
#
#                               Industry_code_ANZSIC06
# 2  ANZSIC06 divisions A-S (excluding classes K633...
# 3  ANZSIC06 divisions A-S (excluding classes K633...
# 4  ANZSIC06 divisions A-S (excluding classes K633...

# %%
#To print Column names
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
#To print column details
df.Value
# Out:
# 0        757,504
# 1        674,890
# 2         49,593
# 3         33,020
# 4        654,404
#           ...
# 41710         52
# 41711         40
# 41712         12
# 41713          5
# 41714         46
# Name: Value, Length: 41715, dtype: object

# %%
#To print columns
df[['Year', 'Units']]
# Out:
#        Year               Units
# 0      2021  Dollars (millions)
# 1      2021  Dollars (millions)
# 2      2021  Dollars (millions)
# 3      2021  Dollars (millions)
# 4      2021  Dollars (millions)
# ...     ...                 ...
# 41710  2013          Percentage
# 41711  2013          Percentage
# 41712  2013          Percentage
# 41713  2013          Percentage
# 41714  2013          Percentage
#
# [41715 rows x 2 columns]

# %%
#To get min value in column
df['Year'].min()
# Out:
# 2013

# %%
#To get max value in column
df['Year'].max()
# Out:
# 2021

# %%
#To get mean 
df['Year'].std()
# Out:
# 2.582019845995168

# %%
#To get all details for the dataframe
df.describe()
# Out:
#               Year
# count  41715.00000
# mean    2017.00000
# std        2.58202
# min     2013.00000
# 25%     2015.00000
# 50%     2017.00000
# 75%     2019.00000
# max     2021.00000

# %%
#To get details greater than 
df[df.Year==2020]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 4635  2020                     Level 1                99999
# 4636  2020                     Level 1                99999
# 4637  2020                     Level 1                99999
# 4638  2020                     Level 1                99999
# 4639  2020                     Level 1                99999
# ...    ...                         ...                  ...
# 9265  2020                     Level 3                 ZZ11
# 9266  2020                     Level 3                 ZZ11
# 9267  2020                     Level 3                 ZZ11
# 9268  2020                     Level 3                 ZZ11
# 9269  2020                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 4635              All industries  Dollars (millions)           H01
# 4636              All industries  Dollars (millions)           H04
# ...

# %%
#To get rows along with operations
df[['Value', 'Year']][df.Year>=2021]
# Out:
#         Value  Year
# 0     757,504  2021
# 1     674,890  2021
# 2      49,593  2021
# 3      33,020  2021
# 4     654,404  2021
# ...       ...   ...
# 4630       77  2021
# 4631       27  2021
# 4632        9  2021
# 4633        4  2021
# 4634       45  2021
#
# [4635 rows x 2 columns]

# %%
df[['Year', 'Units', 'Value']][df.Value==df['Value'].min()]
# Out:
#        Year       Units Value
# 18123  2018  Percentage    -1
# 18124  2018  Percentage    -1
# 23385  2016  Percentage    -1
# 23415  2016  Percentage    -1
# 33974  2014  Percentage    -1
# 37932  2013  Percentage    -1
# 37968  2013  Percentage    -1

# %%
df.set_index('Year')
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# ...                          ...                  ...
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 2021              All industries  Dollars (millions)           H01
# 2021              All industries  Dollars (millions)           H04
# 2021              All industries  Dollars (millions)           H05
# ...

# %%
df.reset_index()
# Out:
#        index  Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0          0  2021                     Level 1                99999
# 1          1  2021                     Level 1                99999
# 2          2  2021                     Level 1                99999
# 3          3  2021                     Level 1                99999
# 4          4  2021                     Level 1                99999
# ...      ...   ...                         ...                  ...
# 41710  41710  2013                     Level 3                 ZZ11
# 41711  41711  2013                     Level 3                 ZZ11
# 41712  41712  2013                     Level 3                 ZZ11
# 41713  41713  2013                     Level 3                 ZZ11
# 41714  41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...

# %%
df.loc[4]
# Out:
# Year                                                                        2021
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H08
# Variable_name                                                  Total expenditure
# Variable_category                                          Financial performance
# Value                                                                    654,404
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 4, dtype: object
